# %%
from matplotlib import pyplot as plt
from scipy.signal import savgol_filter
import numpy as np

# %%
# full_codl = [82.6,81.94,81.66,80.99,80.61,79.83,78.84,77.98,76.63,74.86]
# partial_sspan = [82.6,82.2,81.71,81.37,80.94,80.39,79.51,78.51,77.14,74.66]
# full_codl = full_codl[::-1]
# partial_sspan = partial_sspan[::-1]
# full_codl = [73.81,77.12,78.14,79.22,79.87,80.33,81.09,81.5,81.88,82.13]
# partial_sspan = [74.52,76.67,78.56,79.53,80.25,80.88,81.38,81.84,82.21,82.28]
# full_codl = [74.32,76.72,78.19,79.21,79.97,80.58,81.14,81.57,81.94,82.11]
# partial_sspan = [74.51,76.91,78.5,79.45,80.32,80.89,81.35,81.76,82.14,82.19]
full_codl = [68.61, 71.47,73.42,74.79,75.82,76.7,77.32,77.92,78.43,78.74]
partial_sspan = [68.75,71.71,73.67,75.04,76.12,76.95,77.53,78.06,78.45,78.67]

plt.figure(figsize=(6,4))
plt.rcParams.update({'font.size':14})
plt.plot(np.arange(10, 110, 10),[x for x in savgol_filter(full_codl,3,1)],'c-.')
plt.plot(np.arange(10, 110, 10),[x for x in savgol_filter(partial_sspan,3,1)],'c')
plt.plot(np.arange(10, 110, 10),[x for x in full_codl],'cx')
plt.plot(np.arange(10, 110, 10),[x for x in partial_sspan],'c+')

plt.legend(["Scheme I","Scheme II"],loc=4)
plt.xlabel("Budget (%)")
plt.ylabel("$F_1$ (%)")
plt.rcParams.update({'font.size':14})
plt.xlim((8, 102))
plt.xticks(np.arange(10,110,10))

# plt.subplot(212)
# plt.plot(np.arange(10,100,10),[100*x for x in savgol_filter(AllF1_samMod_rel2,3,1)],'k')
# plt.plot(np.arange(10,100,10),[100*x for x in AllF1_samMod_rel2],'k+')

# plt.xlabel("Completeness (%)")
# plt.ylabel("$F_1$ (%)")
# plt.rcParams.update({'font.size':16})
# plt.xlim((0, 100))
# plt.ylim((58, 60))
plt.tight_layout()
plt.grid()
plt.savefig("srl_result.pdf")
plt.show()

# plt.figure()
# # plt.errorbar(x=np.arange(0.1, 1.0, 0.1),y=AllF1_samMod_imp, yerr=AllF1_samMod_imp_std)
# # plt.errorbar(x=np.arange(0.1, 1.0, 0.2),y=AllF1_samMod_imp, yerr=AllF1_samMod_imp_std)
# plt.plot(np.arange(0.1, 1.0, 0.1),savgol_filter(AllF1_samMod_imp,3,1),'k')
# plt.show()
# Out:
# /home/qning2/Software/anaconda2/lib/python2.7/site-packages/scipy/signal/_arraytools.py:45: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   b = a[a_slice]

# %%
# full_codl = [85.82,86.91,87.57,87.95,88.34,88.73,88.94,89.18,89.53,89.64]
# partial_sspan = [85.75,87.19,87.79,88.3,88.49,88.79,89.06,89.36,89.57,89.6]
# full_codl = [85.58,86.61,87.38,87.81,88.28,88.65,88.92,89.23,89.52,89.63]
# partial_sspan = [85.67,86.79,87.54,88.01,88.41,88.83,89.06,89.28,89.53,89.66]
partial_sspan = [85.51,86.73,87.45,87.93,88.41,88.76,89.07,89.29,89.50,89.66]
full_codl = [85.55,86.58,87.33,87.89,88.35,88.71,88.94,89.23,89.48,89.67]

plt.figure(figsize=(6,4))
plt.rcParams.update({'font.size':14})
plt.plot(np.arange(10, 110, 10),[x for x in savgol_filter(full_codl,3,1)],'m-.')
plt.plot(np.arange(10, 110, 10),[x for x in savgol_filter(partial_sspan,3,1)],'m')
plt.plot(np.arange(10, 110, 10),[x for x in full_codl],'mx')
plt.plot(np.arange(10, 110, 10),[x for x in partial_sspan],'m+')

plt.legend(["Scheme I","Scheme II"],loc=4)
plt.xlabel("Budget (%)")
plt.ylabel("$F_1$ (%)")
plt.xlim((8, 102))
plt.xticks(np.arange(10,110,10))


# plt.subplot(212)
# plt.plot(np.arange(10,100,10),[100*x for x in savgol_filter(AllF1_samMod_rel2,3,1)],'k')
# plt.plot(np.arange(10,100,10),[100*x for x in AllF1_samMod_rel2],'k+')

# plt.xlabel("Completeness (%)")
# plt.ylabel("$F_1$ (%)")
# plt.rcParams.update({'font.size':16})
# plt.xlim((0, 100))
# plt.ylim((58, 60))
plt.tight_layout()
plt.grid()
plt.savefig("chunker_result.pdf")
plt.show()
